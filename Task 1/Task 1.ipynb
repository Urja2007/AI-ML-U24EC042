# %%
import pandas as pd

# %%
df = pd.read_csv('/content/student_performance.csv')
df
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
total_number_of_students = len(df)
total_number_of_students
# Out:
# 1000

# %%
df.shape
# Out:
# (1000, 16)

# %%
x = df.loc[df['study_hours_per_day']>2]
x #no_of_student_studied_greater_than_2hours
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 1        S1001   20  Female                  6.9                 2.8
# 4        S1004   19  Female                  5.0                 4.4
# 5        S1005   24    Male                  7.2                 1.3
# 6        S1006   21  Female                  5.6                 1.5
# 7        S1007   21  Female                  4.3                 1.0
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
len(x)
# Out:
# 846

# %%
x.shape
# Out:
# (846, 16)

# %%
x.loc[:,'study_hours_per_day']
# Out:
# 0      0.0
# 2      1.4
# 3      1.0
# 16     1.0
# 19     1.8
#       ...
# 978    1.6
# 979    1.3
# 986    1.1
# 989    1.0
# 994    1.6
# Name: study_hours_per_day, Length: 133, dtype: float64

# %%
y = df.loc[df['exam_score']>35]
y #student who passed
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 4        S1004   19  Female                  5.0                 4.4
# 5        S1005   24    Male                  7.2                 1.3
# 6        S1006   21  Female                  5.6                 1.5
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
len(y)
# Out:
# 976

# %%
z = x.loc[x['exam_score']>35]
z #Students who studied > 2 hours and passed
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 1        S1001   20  Female                  6.9                 2.8
# 4        S1004   19  Female                  5.0                 4.4
# 5        S1005   24    Male                  7.2                 1.3
# 6        S1006   21  Female                  5.6                 1.5
# 7        S1007   21  Female                  4.3                 1.0
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
len(z)
# Out:
# 111

# %%
z.iloc[: , 3]
# Out:
# 1      6.9
# 4      5.0
# 5      7.2
# 6      5.6
# 7      4.3
#       ...
# 995    2.6
# 996    2.9
# 997    3.0
# 998    5.4
# 999    4.3
# Name: study_hours_per_day, Length: 845, dtype: float64

# %%
z.iloc[: , 15]
# Out:
# 1      100.0
# 4       66.4
# 5      100.0
# 6       89.8
# 7       72.6
#        ...
# 995     76.1
# 996     65.9
# 997     64.4
# 998     69.7
# 999     74.9
# Name: exam_score, Length: 845, dtype: float64

# %%
w = x.loc[x['exam_score']<35]
w #Students who studied > 2 hours and failed
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 471      S1471   24  Female                  2.2                 3.1
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 471            1.1            No                   96.5          6.9
#
#     diet_quality  exercise_frequency parental_education_level  \
# 471         Fair                   0                 Bachelor
#
#     internet_quality  mental_health_rating extracurricular_participation  \
# 471             Poor                     4                            No
#
#      exam_score
# 471        33.8

# %%
#Percentage of students who passed among those who studied > 2 hours
a = float(len(z))
b= float(len(x))
percentage = (a/b)*100
percentage
# Out:
# 99.88179669030734

# %%
# Use Bayes Theorem to compute:
# ➤ Probability that a student studied > 2h given they passed
c = float(len(df))
d = float(len(y))
c # total no.of student
b # total no_of_student_studied_greater_than_2hours
d #student who passed
a #Students who studied > 2 hours and passed
# Out:
# 845.0

# %%
a #Students who studied > 2 hours and passed
# Out:
# 845.0

# %%
b # total no_of_student_studied_greater_than_2hours
# Out:
# 846.0

# %%
c # total no.of student
# Out:
# 1000.0

# %%
d #student who passed
# Out:
# 976.0

# %%
p1= d/c  #Probability of student who passed P(Passed)
p1
# Out:
# 0.976

# %%
p2 = b/c # P(Studied>2h)
p2
# Out:
# 0.846

# %%
p3 = a/b #P(Passed∣Studied>2h)
p3
# Out:
# 0.9988179669030733

# %%
#According to Bayes Theorem
#Probability that a student studied > 2h given they passed
# p = [P(Passed∣Studied>2h)⋅P(Studied>2h)] / P(Passed)
# Out:
#   File "/tmp/ipython-input-55-1244435250.py", line 6
#     ​
#     ^
# SyntaxError: invalid non-printable character U+200B

# %%
probability = (p3*p2)/p1
probability
# Out:
# 0.8657786885245902
